# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline

# %%
recent_grads= pd.read_csv("C:\\Users\\Ruben Pena\\Desktop\\Dataquest-ExploratoryViz\\recent-grads.csv")
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
raw_data_count = len(recent_grads.index)
raw_data_count
# Out:
# 173

# %%
recent_grads.shape
# Out:
# (173, 21)

# %%
recent_grads = recent_grads.dropna()
recent_grads.shape
# Out:
# (172, 21)

# %%
cleaned_data_count = len(recent_grads.index)
cleaned_data_count
# Out:
# 172

# %% [markdown]
# # Scatter Plots

# %%
recent_grads.plot(x='Sample_size', y='Employed', kind='scatter')

# %%
recent_grads.plot(x='Sample_size', y='Employed', kind='scatter', title='Employed vs. Sample_size', figsize=(5,10))

# %%
SSvEmp = recent_grads.plot(x='Sample_size', y='Employed', kind='scatter')
SSvEmp.set_title('Employed vs. Sample_size')

# %%
SSvMed = recent_grads.plot(x='Sample_size', y='Median', kind ='scatter')
SSvMed.set_title("Sample Size vs. Median")

# %%
SSvUR=recent_grads.plot(x='Sample_size',y='Unemployment_rate', kind='scatter')
SSvUR.set_title("Sample_size  vs. Unemployment Rate")

# %%
FTvM=recent_grads.plot(x='Full_time',y='Median',kind='scatter')
FTvM.set_title("Full_time vs. Median")

# %%
WvUR=recent_grads.plot(x='ShareWomen',y='Unemployment_rate',kind='scatter')
WvUR.set_title("Share of Women vs. Unemployment Rate")

# %%
MvMed=recent_grads.plot(x='Men',y='Median',kind='scatter')
MvMed.set_title("Men vs. Median")

# %%
WvMed=recent_grads.plot(x='Women',y='Median',kind='scatter')
WvMed.set_title("Women vs. Median")

# %% [markdown]
# # Histograms

# %%
recent_grads.sort_values(by= ["Total"],ascending=False)
# Out:
#      Rank  Major_code                                              Major  \
# 145   146        5200                                         PSYCHOLOGY
# 76     77        6203             BUSINESS MANAGEMENT AND ADMINISTRATION
# 123   124        3600                                            BIOLOGY
# 57     58        6200                                   GENERAL BUSINESS
# 93     94        1901                                     COMMUNICATIONS
# 34     35        6107                                            NURSING
# 77     78        6206                   MARKETING AND MARKETING RESEARCH
# 40     41        6201                                         ACCOUNTING
# 137   138        3301                    ENGLISH LANGUAGE AND LITERATURE
# 78     79        5506                   POLITICAL SCIENCE AND GOVERNMENT
# 35     36        6207                                            FINANCE
# 138   139        2304                               ELEMENTARY EDUCATION
# ...

# %%
SSmax=recent_grads['Sample_size'].max()
SSmin=recent_grads['Sample_size'].min()
ss=recent_grads["Sample_size"].hist(bins='doane',range=(SSmin,SSmax))
ss.set_xlabel('Sample Sizes')
ss.set_ylabel('Number of Samples')
ss.set_title('Sample Size')

# %%
Medmax=recent_grads['Median'].max()
Medmin=recent_grads['Median'].min()
MedAx=recent_grads["Median"].hist(bins='sturges',range=(Medmin,Medmax))
MedAx.set_xlabel('Number of Emps')
MedAx.set_ylabel('Median Salary')
MedAx.set_title('Median Salary of FT Workers')

# %% [markdown]
# ## Most Common Median Salary Range
# The histogram above shows that the most common median salary range is roughly $30k to $40k with over 90 of the 172 major being in this range.

# %%
Empmax=recent_grads['Employed'].max()
Empmin=recent_grads['Employed'].min()
EmpAx=recent_grads["Employed"].hist(bins='sturges',range=(Empmin,Empmax))
EmpAx.set_xlabel('Number of Emps')
EmpAx.set_ylabel('Employed')
EmpAx.set_title('Number Employed')

# %%
FTmax=recent_grads['Full_time'].max()
FTmin=recent_grads['Full_time'].min()
FtAx=recent_grads["Full_time"].hist(bins='sturges',range=(FTmin,FTmax))
FtAx.set_xlabel('Number of FT Emps')
FtAx.set_ylabel('Employed-FT')
FtAx.set_title('Number employed 35 hours or more')

# %%
recent_grads.sort_values(by= ["ShareWomen"],ascending=False)
# Out:
#      Rank  Major_code                                              Major  \
# 164   165        2307                          EARLY CHILDHOOD EDUCATION
# 163   164        6102      COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 51     52        6104                         MEDICAL ASSISTING SERVICES
# 138   139        2304                               ELEMENTARY EDUCATION
# 150   151        2901                       FAMILY AND CONSUMER SCIENCES
# 100   101        2310                            SPECIAL NEEDS EDUCATION
# 156   157        5403          HUMAN SERVICES AND COMMUNITY ORGANIZATION
# 151   152        5404                                        SOCIAL WORK
# 34     35        6107                                            NURSING
# 88     89        6199           MISCELLANEOUS HEALTH MEDICAL PROFESSIONS
# 172   173        3501                                    LIBRARY SCIENCE
# 128   129        2313                       LANGUAGE AND DRAMA EDUCATION
# ...

# %%
SWmax=recent_grads['ShareWomen'].max()
SWmin=recent_grads['ShareWomen'].min()
SwAx=recent_grads["ShareWomen"].hist(bins='fd',range=(SWmin,SWmax))
SwAx.set_xlabel('Share of Women (decimal)')
SwAx.set_ylabel('Number of Majors')
SwAx.set_title('Women as a share of Total Grads')

# %%
recent_grads.sort_values(by= ["Unemployment_rate"],ascending=False)
# Out:
#      Rank  Major_code                                              Major  \
# 5       6        2418                                NUCLEAR ENGINEERING
# 89     90        5401                              PUBLIC ADMINISTRATION
# 84     85        2107         COMPUTER NETWORKING AND TELECOMMUNICATIONS
# 170   171        5202                                CLINICAL PSYCHOLOGY
# 29     30        5402                                      PUBLIC POLICY
# 105   106        2001                         COMMUNICATION TECHNOLOGIES
# 1       2        2416                     MINING AND MINERAL ENGINEERING
# 53     54        2101           COMPUTER PROGRAMMING AND DATA PROCESSING
# 79     80        5504                                          GEOGRAPHY
# 58     59        1401                                       ARCHITECTURE
# 118   119        6110                        COMMUNITY AND PUBLIC HEALTH
# 70     71        5205           INDUSTRIAL AND ORGANIZATIONAL PSYCHOLOGY
# ...

# %%
URmax=recent_grads['Unemployment_rate'].max()
URmin=recent_grads['Unemployment_rate'].min()
UrAx=recent_grads["Unemployment_rate"].hist(bins='fd',range=(URmin,URmax))
UrAx.set_xlabel('Unemployment Rate')
UrAx.set_ylabel('Number of Majors')
UrAx.set_title('Unemployement Rates against Majors')

# %%
recent_grads.sort_values(by= ["Men"],ascending=False)
# Out:
#      Rank  Major_code                                              Major  \
# 76     77        6203             BUSINESS MANAGEMENT AND ADMINISTRATION
# 57     58        6200                                   GENERAL BUSINESS
# 35     36        6207                                            FINANCE
# 123   124        3600                                            BIOLOGY
# 20     21        2102                                   COMPUTER SCIENCE
# 40     41        6201                                         ACCOUNTING
# 78     79        5506                   POLITICAL SCIENCE AND GOVERNMENT
# 36     37        5501                                          ECONOMICS
# 145   146        5200                                         PSYCHOLOGY
# 8       9        2414                             MECHANICAL ENGINEERING
# 94     95        5301               CRIMINAL JUSTICE AND FIRE PROTECTION
# 77     78        6206                   MARKETING AND MARKETING RESEARCH
# ...

# %%
MenMax=recent_grads["Men"].max()
MenMin=recent_grads["Men"].min()
MenAx=recent_grads["Men"].hist(bins='sturges',range=(MenMin,MenMax))
MenAx.set_xlabel('Men')
MenAx.set_ylabel('Majors')
MenAx.set_title('Male graduates')

# %%
Wmax=recent_grads['Women'].max()
Wmin=recent_grads['Women'].min()
WmAx=recent_grads["Women"].hist(bins='sturges',range=(Wmin,Wmax))
WmAx.set_xlabel('Women')
WmAx.set_ylabel('Majors')
WmAx.set_title('Women Graduates')

# %% [markdown]
# # Step 4
# #2 Scatter Matrix Plots

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size','Median']], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E74B02B0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E76C3518>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size','Median','Unemployment_rate']], figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E7666D30>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E7B4DCF8>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Major_code','Men']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E7E74588>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E7DE74E0>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Major_code','Women']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E7F6F978>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E80DCEF0>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Major_code','Total','Women']], figsize=(6,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E81C7F28>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E9820940>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Major_code','Total','Men']], figsize=(5,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E9993160>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E9D037F0>]], dtype=object)

# %%
scatter_matrix(recent_grads[['Major_code','Women','Men']], figsize=(5,5))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001E2E93F6048>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001E2EA18BE10>]], dtype=object)

# %% [markdown]
# # Step 5
# #2 Bar Plots

# %%
recent_grads[:5].plot.bar(x='Major', y='Women')

# %%
recent_grads[:5].plot.bar(x='Major', y='Women')

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate', legend=False)

# %%
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate', legend=False)

# %% [markdown]
# ## Use a grouped bar plot to compare the number of men with the number of women in each category of majors

# %%
pvt_tbl = recent_grads.pivot_table(index='Major_category', values=['Men','Women'],aggfunc=np.sum)
pvt_tbl.plot.bar(x=pvt_tbl.index,y=['Men','Women'])

# %% [markdown]
# ## Use a box plot to explore the distributions of median salaries and unemployment rate

# %%
recent_grads["Median"].plot(kind='box')

# %%
recent_grads["Unemployment_rate"].plot(kind='box')

# %% [markdown]
# ## Use a hexagonal bin plot to visualize the columns that had dense scatter plots from earlier in the project

# %%
recent_grads.plot(kind='hexbin', x='Median',y='Unemployment_rate',gridsize=20)

# %%
recent_grads.plot(kind='hexbin', x='Unemployment_rate',y='Men',gridsize=20)

# %%
recent_grads.plot(kind='hexbin', x='Unemployment_rate',y='Women',gridsize=20)
